# %%
# sshubhakar.msismpl2026@learner.manipal.edu
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
import numpy as np
import matplotlib.pyplot as plt

# data=pd.read_csv("data/income_data.csv")
data=pd.read_csv("data/Salary_Data.csv")

df = pd.DataFrame(data)

# x= df[["income"]]
# y=df["happiness"]

x= df[["YearsExperience"]]
y=df["Salary"]

x_train,x_test,y_train,y_test=train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

model = LinearRegression()
model.fit(x_train,y_train)

y_pred = model.predict(x_test)

print("Intercept:",model.intercept_)
print("Slope:",model.coef_[0])
print("Actual Value:",y_test.values)
print("predicted values:",y_pred)

mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test,y_pred)
print("MAE:",mae)
print("MSE",mse)
print("RMSE",rmse)
print("R Squared",r2)

plt.scatter(x_train, y_train,color='green')
plt.scatter(x_test,y_test,color="red",)

# plt.scatter(x,y,color="blue",label="Actual Data")
# plt.plot(x_test,y_pred,color="red",label="Regression line")

plt.plot(x_train,model.predict(x_train),color="blue",label="Regression line")

# plt.xlabel("income")
# plt.ylabel("happiness")
# plt.title("income v/s happiness")

plt.xlabel("Years Experience")
plt.ylabel("Salary")
plt.title("Years Experience v/s Salary")

plt.legend()
plt.show()

# %%
experience = np.array([[7.5]]) #Convert single dimension into 2 dimension
predicted_salary=  model.predict(experience)

print(f"{predicted_salary[0]:.2f}")

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV

#Create a pipeline:
# 1. Standardize the predictors - Computation for calculation of ridge value
# 2. Apply Ridge Regression
model = make_pipeline(
    StandardScaler(),
    RidgeCV(alphas=[0.01,0.1,1,10,100])
)

model.fit(x_train, y_train)

ridge_model=model.named_steps["ridgecv"]
print("Best alpha:",ridge_model.alpha_)

y_pred = model.predict(x_test)

print("Actual Value:",y_test.values)
print("predicted values:",y_pred)

mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test,y_pred)
print("MAE:",mae)
print("MSE",mse)
print("RMSE",rmse)
print("R Squared",r2)

plt.scatter(x_train, y_train,color='green')
plt.scatter(x_test,y_test,color="red",)
plt.plot(x_train,model.predict(x_train),color="blue",label="Regression line")

plt.xlabel("Years Experience")
plt.ylabel("Salary")
plt.title("Years Experience v/s Salary")

plt.legend()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge

X = np.array([
    [1,8],
    [2,13],
    [3,22],
    [4,27],
    [5,36]
])
#Pick the alpha giving the smallest coefficient values
y=np.array([40,48,57,65,74])
scalar =StandardScaler()
x_scaled = scalar.fit_transform(X)
model = Ridge(alpha=100.0)
model.fit(x_scaled,y)
print(model.intercept_)
print(model.coef_)

# Apply ridge regression to existing linear regression code and check the best alpha value for each
# Out:
# 56.8
# [0.05951126 0.05933966]
